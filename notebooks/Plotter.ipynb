# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0, '../')
from plotter import Plotter
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plotter = Plotter()

# %%
import numpy as np
values = list(np.random.rand(10000))

# %%
plotter.rank_plot(values)
