# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0, '../')
from color_theory import ColorTheory

# %%
ct = ColorTheory()

# %%
ct.view_colors()

# %%
ct.view_color_palettes()
# Out:
# deep
# muted
# pastel
# bright
# dark
# colorblind
# Blues
# Greens
# Reds
# BrBG
# RdBu_r
# coolwarm

# %%
ct.get_color()
# Out:
# '#E9967A'
